# %% [markdown]
# <img src=https://lstms-brainybits.s3.ap-south-1.amazonaws.com/green+logo.png width="300" height="200" style="float: left; margin-right: 8px;">

# %% [markdown]
# We believe in empowering individuals with the
# knowledge and skills they need to become lifelong
# learners. Our self-learning website offers a diverse
# range of high-quality, interactive courses.
# **All rights reserved to BrainyBits. Unauthorized reproduction or distribution of this content is prohibited.**

# %% [markdown]
# # Working with files

# %% [markdown]
# ### 1. Reading of csv files

# %%
import pandas as pd


# Read CSV file
df = pd.read_csv('train.csv')

# Display the DataFrame
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# ### Writing files

# %%
# Assuming 'df' is your DataFrame
df.to_csv('output.csv', index=False)

# %% [markdown]
# ### 2. Understanding the dataset

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
# Display first 5 rows of the dataset

df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
# Display last 5 rows of the dataset

df.tail()
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 886    male  27.0      0      0      211536  13.00   NaN        S
# 887  female  19.0      0      0      112053  30.00   B42        S
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0      0      111369  30.00  C148        C
# 890    male  32.0      0      0      370376   7.75   NaN        Q

# %%
# Display basic information about the dataset

print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB
# None

# %%
# Display descriptive statistics of the dataset

print(df.describe())
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
# Display the column names

print(df.columns)
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
# Display the data types of each column

print(df.dtypes)
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
# Display the number of rows and columns

print(df.shape)
# Out:
# (891, 12)

# %% [markdown]
# ### 3. Insights of the dataset

# %%
# Check for missing values
print(df.isnull().sum())
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
# Select a specific column
name_data = df['Cabin']

# Select multiple columns
selected_columns = df[['Ticket', 'Fare']]

# %%
name_data
# Out:
# 0       NaN
# 1       C85
# 2       NaN
# 3      C123
# 4       NaN
#        ...
# 886     NaN
# 887     B42
# 888     NaN
# 889    C148
# 890     NaN
# Name: Cabin, Length: 891, dtype: object

# %%
selected_columns
# Out:
#                Ticket     Fare
# 0           A/5 21171   7.2500
# 1            PC 17599  71.2833
# 2    STON/O2. 3101282   7.9250
# 3              113803  53.1000
# 4              373450   8.0500
# ..                ...      ...
# 886            211536  13.0000
# 887            112053  30.0000
# 888        W./C. 6607  23.4500
# 889            111369  30.0000
# 890            370376   7.7500
#
# [891 rows x 2 columns]

# %%
# Filter rows based on a condition
below_40_age_data = df[df['Age'] > 40]

# %%
below_40_age_data
# Out:
#      PassengerId  Survived  Pclass  \
# 6              7         0       1
# 11            12         1       1
# 15            16         1       2
# 33            34         0       2
# 35            36         0       1
# ..           ...       ...     ...
# 862          863         1       1
# 865          866         1       2
# 871          872         1       1
# 873          874         0       3
# 879          880         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 6                              McCarthy, Mr. Timothy J    male  54.0      0
# 11                            Bonnell, Miss. Elizabeth  female  58.0      0
# 15                    Hewlett, Mrs. (Mary D Kingcome)   female  55.0      0
# 33                               Wheadon, Mr. Edward H    male  66.0      0
# 35                      Holverson, Mr. Alexander Oskar    male  42.0      1
# ..                                                 ...     ...   ...    ...
# ...

# %%
# Sort data by a specific column
sorted_data = df.sort_values(by='Age', ascending=True)

# %%
sorted_data
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 803          804         1       3           Thomas, Master. Assad Alexander
# 755          756         1       2                 Hamalainen, Master. Viljo
# 644          645         1       3                    Baclini, Miss. Eugenie
# 469          470         1       3             Baclini, Miss. Helene Barbara
# 78            79         1       2             Caldwell, Master. Alden Gates
# ..           ...       ...     ...                                       ...
# 859          860         0       3                          Razi, Mr. Raihed
# 863          864         0       3         Sage, Miss. Dorothy Edith "Dolly"
# 868          869         0       3               van Melkebeke, Mr. Philemon
# 878          879         0       3                        Laleff, Mr. Kristo
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
#
# ...

# %% [markdown]
# ### 4. Charts

# %%
## Bar Chart

import matplotlib.pyplot as plt
import numpy as np

plt.bar(df["Sex"], df["Age"])
plt.xlabel('Sex')
plt.ylabel('Age')
plt.title(' Bar Chart Age Vs Sex')
plt.show()

# %%
# Plotting scatter plot

plt.scatter(df["Age"], df["Fare"])
plt.xlabel('Age')
plt.ylabel('Fare')
plt.title('Scatter Plot')
plt.show()

# %%
# Plotting box plot
import seaborn as sns

sns.boxplot(data=df)
plt.xlabel('Groups')
plt.ylabel('Values')
plt.title('Box Plot')
plt.show()

# %%
# Plotting histogram

plt.hist(df["Age"], bins=30,  alpha=0.7)
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.title('Histogram')
plt.show()

# %% [markdown]
# ### 5. Data Cleaning

# %%
# Drop rows with missing values
df_cleaned = df.dropna()

# %%
df_cleaned
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 3              4         1       1
# 6              7         0       1
# 10            11         1       3
# 11            12         1       1
# ..           ...       ...     ...
# 871          872         1       1
# 872          873         0       1
# 879          880         1       1
# 887          888         1       1
# 889          890         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 6                              McCarthy, Mr. Timothy J    male  54.0      0
# 10                     Sandstrom, Miss. Marguerite Rut  female   4.0      1
# 11                            Bonnell, Miss. Elizabeth  female  58.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
print(df_cleaned.isnull().sum())
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Cabin          0
# Embarked       0
# dtype: int64

# %%
print(df.isnull().sum())
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
# Fill missing values with a specific value
df_filled = df.fillna(100)

# %%
print(df_cleaned.isnull().sum())
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Cabin          0
# Embarked       0
# dtype: int64

# %%
# Fill missing values with the mean of the column
df.fillna(df["Age"].mean(), inplace=True)

# %%
df.isnull().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Cabin          0
# Embarked       0
# dtype: int64

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare      Cabin Embarked
# 0      0         A/5 21171   7.2500  29.699118        S
# 1      0          PC 17599  71.2833        C85        C
# 2      0  STON/O2. 3101282   7.9250  29.699118        S
# 3      0            113803  53.1000       C123        S
# ...

# %%
# Remove duplicate rows based on all columns
df.drop_duplicates(inplace=True)

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex        Age  \
# 0                              Braund, Mr. Owen Harris    male  22.000000
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.000000
# 2                               Heikkinen, Miss. Laina  female  26.000000
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.000000
# 4                             Allen, Mr. William Henry    male  35.000000
# ..                                                 ...     ...        ...
# ...

# %%
# Rename columns for clarity
df.rename(columns={'SibSp_New': 'SibSp'}, inplace=False)
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex        Age  \
# 0                              Braund, Mr. Owen Harris    male  22.000000
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.000000
# 2                               Heikkinen, Miss. Laina  female  26.000000
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.000000
# 4                             Allen, Mr. William Henry    male  35.000000
# ..                                                 ...     ...        ...
# ...

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp_New  \
# 0                            Braund, Mr. Owen Harris    male  22.0          1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0          1
# 2                             Heikkinen, Miss. Laina  female  26.0          0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0          1
# 4                           Allen, Mr. William Henry    male  35.0          0
#
#    Parch            Ticket     Fare      Cabin Embarked
# 0      0         A/5 21171   7.2500  29.699118        S
# 1      0          PC 17599  71.2833        C85        C
# 2      0  STON/O2. 3101282   7.9250  29.699118        S
# 3      0            113803  53.1000       C123        S
# ...

# %%
# Convert a column to a different data type
df['Pclass_New'] = df['Pclass'].astype('int')

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp_New',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked', 'Pclass_New'],
#       dtype='object')

# %%
# Filter out rows with values outside a specific range
df_new_data = df[(df['SibSp_New'] >= 50) & (df['SibSp_New'] <= 85)]

# %%
df_new_data.head()
# Out:
# Empty DataFrame
# Columns: [PassengerId, Survived, Pclass, Name, Sex, Age, SibSp_New, Parch, Ticket, Fare, Cabin, Embarked, Pclass_New]
# Index: []

# %% [markdown]
# ### 6. Data Preprocessing

# %%
# Drop columns that are not needed for analysis
df = df.drop(['SibSp_New', 'Pclass_New'], axis=1)

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'Parch',
#        'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
df["Sex"].value_counts()
# Out:
# Sex
# male      577
# female    314
# Name: count, dtype: int64

# %%
# Using one-hot encoding for categorical variables
df = pd.get_dummies(df, columns=['Sex'])

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name   Age  Parch  \
# 0                            Braund, Mr. Owen Harris  22.0      0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  38.0      0
# 2                             Heikkinen, Miss. Laina  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  35.0      0
# 4                           Allen, Mr. William Henry  35.0      0
#
#              Ticket     Fare      Cabin Embarked  Sex_female  Sex_male
# 0         A/5 21171   7.2500  29.699118        S       False      True
# 1          PC 17599  71.2833        C85        C        True     False
# 2  STON/O2. 3101282   7.9250  29.699118        S        True     False
# 3            113803  53.1000       C123        S        True     False
# ...

# %%
from sklearn.preprocessing import LabelEncoder
# Label encode a categorical column
label_encoder = LabelEncoder()
df['Sex_female'] = label_encoder.fit_transform(df['Sex_female'])

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name        Age  Parch  \
# 0                              Braund, Mr. Owen Harris  22.000000      0
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  38.000000      0
# 2                               Heikkinen, Miss. Laina  26.000000      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  35.000000      0
# 4                             Allen, Mr. William Henry  35.000000      0
# ..                                                 ...        ...    ...
# ...

# %%
from sklearn.preprocessing import StandardScaler
# Standardize numeric columns
scaler = StandardScaler()
df_filled[['Pclass_New_2', 'Age_New_2']] = scaler.fit_transform(df_filled[['Pclass', 'Age']])

# %%
df_filled
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex    Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male   22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female   38.0      1
# 2                               Heikkinen, Miss. Laina  female   26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female   35.0      1
# 4                             Allen, Mr. William Henry    male   35.0      0
# ...

# %% [markdown]
# ### 7. Data Manipulation

# %%
import pandas as pd

# Sample DataFrame 1
df1 = pd.DataFrame({
    'common_column': [1, 2, 3, 4],
    'column_df1': ['A', 'B', 'C', 'D'],
    'value_df1': [10, 20, 30, 40]
})

# Sample DataFrame 2
df2 = pd.DataFrame({
    'common_column': [2, 3, 4, 5],
    'column_df2': ['X', 'Y', 'Z', 'W'],
    'value_df2': [50, 60, 70, 80]
})

# Merging DataFrames based on a common column
merged_df = pd.merge(df1, df2, on='common_column')

# Displaying the result
print("DataFrame 1:")
print(df1)
print("\nDataFrame 2:")
print(df2)
print("\nMerged DataFrame:")
print(merged_df)
# Out:
# DataFrame 1:
#    common_column column_df1  value_df1
# 0              1          A         10
# 1              2          B         20
# 2              3          C         30
# 3              4          D         40
#
# DataFrame 2:
#    common_column column_df2  value_df2
# 0              2          X         50
# 1              3          Y         60
# 2              4          Z         70
# 3              5          W         80
#
# Merged DataFrame:
#    common_column column_df1  value_df1 column_df2  value_df2
# 0              2          B         20          X         50
# 1              3          C         30          Y         60
# 2              4          D         40          Z         70

# %%
import pandas as pd

# Sample DataFrame 1
df1 = pd.DataFrame({
    'common_column': [1, 2, 3, 4],
    'column_df1': ['A', 'B', 'C', 'D'],
    'value_df1': [10, 20, 30, 40]
})

# Sample DataFrame 2
df2 = pd.DataFrame({
    'common_column': [5, 6, 7, 8],
    'column_df2': ['X', 'Y', 'Z', 'W'],
    'value_df2': [50, 60, 70, 80]
})

# Concatenating DataFrames along rows
concatenated_df = pd.concat([df1, df2], axis=0)

# Displaying the result
print("DataFrame 1:")
print(df1)
print("\nDataFrame 2:")
print(df2)
print("\nConcatenated DataFrame:")
print(concatenated_df)
# Out:
# DataFrame 1:
#    common_column column_df1  value_df1
# 0              1          A         10
# 1              2          B         20
# 2              3          C         30
# 3              4          D         40
#
# DataFrame 2:
#    common_column column_df2  value_df2
# 0              5          X         50
# 1              6          Y         60
# 2              7          Z         70
# 3              8          W         80
#
# Concatenated DataFrame:
#    common_column column_df1  value_df1 column_df2  value_df2
# 0              1          A       10.0        NaN        NaN
# 1              2          B       20.0        NaN        NaN
# 2              3          C       30.0        NaN        NaN
# 3              4          D       40.0        NaN        NaN
# 0              5        NaN        NaN          X       50.0
# 1              6        NaN        NaN          Y       60.0
# 2              7        NaN        NaN          Z       70.0
# ...

# %%
import pandas as pd

# Sample DataFrame 1
df1 = pd.DataFrame({
    'common_column': [1, 2, 3, 4],
    'column_df1': ['A', 'B', 'C', 'D'],
    'value_df1': [10, 20, 30, 40]
})

# Sample DataFrame 2
df2 = pd.DataFrame({
    'common_column': [5, 6, 7, 8],
    'column_df2': ['X', 'Y', 'Z', 'W'],
    'value_df2': [50, 60, 70, 80]
})

# Concatenating DataFrames along rows
concatenated_df = pd.concat([df1, df2], axis=0)

# Displaying the result
print("DataFrame 1:")
print(df1)
print("\nDataFrame 2:")
print(df2)
print("\nConcatenated DataFrame:")
print(concatenated_df)
# Out:
# DataFrame 1:
#    common_column column_df1  value_df1
# 0              1          A         10
# 1              2          B         20
# 2              3          C         30
# 3              4          D         40
#
# DataFrame 2:
#    common_column column_df2  value_df2
# 0              5          X         50
# 1              6          Y         60
# 2              7          Z         70
# 3              8          W         80
#
# Concatenated DataFrame:
#    common_column column_df1  value_df1 column_df2  value_df2
# 0              1          A       10.0        NaN        NaN
# 1              2          B       20.0        NaN        NaN
# 2              3          C       30.0        NaN        NaN
# 3              4          D       40.0        NaN        NaN
# 0              5        NaN        NaN          X       50.0
# 1              6        NaN        NaN          Y       60.0
# 2              7        NaN        NaN          Z       70.0
# ...
